# %% [markdown]
# # Importing Library

# %%
# To perform Mathematical Operation
import numpy as np
# To manipulate dataframes and series
import pandas as pd
# To Visualize data and format chart style
import matplotlib.pyplot as plt
# To Visualize data in more efficient manner and statistical Visualiztion 
import seaborn as sns
# To get country name from country code
import pycountry

# %% [markdown]
# # Reading Dataset

# %%
df = pd.read_csv('Hotel Bookings.csv')

# %% [markdown]
# # Know Your Data

# %% [markdown]
# ## Dataset First View

# %%
# Print first 5 rows of dataframe
pd.set_option('display.max_columns', None)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# Print last 5 rows of dataframe
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# Print random 5 rows of dataframe
np.random.seed(101)
df.sample(5)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 54215    City Hotel            1         74               2016
# 42638    City Hotel            0         22               2015
# 8295   Resort Hotel            1        197               2016
# 82129    City Hotel            1         99               2016
# 8493   Resort Hotel            1        157               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 54215               July                        28                          9
# 42638          September                        37                          8
# 8295           September                        39                         21
# 82129           February                         8                         19
# 8493             October                        40                          1
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# ...

# %% [markdown]
# ## Dataset Rows and Columns Count

# %%
# Print Number of Rows dataframe
print(f'Number of rows in dataset is {df.shape[0]}')
# Out:
# Number of rows in dataset is 119390

# %%
# Print Number of Columns dataframe
print(f'Number of columns in dataset is {df.shape[1]}')
# Out:
# Number of columns in dataset is 32

# %%
# Print rows of dataframe
df.index
# Out:
# RangeIndex(start=0, stop=119390, step=1)

# %%
# Print colmuns of dataframe
for col in df.columns:
    print(col)
# Out:
# hotel
# is_canceled
# lead_time
# arrival_date_year
# arrival_date_month
# arrival_date_week_number
# arrival_date_day_of_month
# stays_in_weekend_nights
# stays_in_week_nights
# adults
# children
# babies
# meal
# country
# market_segment
# distribution_channel
# is_repeated_guest
# previous_cancellations
# previous_bookings_not_canceled
# reserved_room_type
# assigned_room_type
# booking_changes
# deposit_type
# agent
# company
# days_in_waiting_list
# customer_type
# adr
# required_car_parking_spaces
# total_of_special_requests
# reservation_status
# reservation_status_date

# %% [markdown]
# ## Basic Information Of Dataset

# %%
# Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Datatype of each column
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
# Print All Numerical Columns
for i in df.select_dtypes(exclude='object').columns:
    print(i)
# Out:
# is_canceled
# lead_time
# arrival_date_year
# arrival_date_week_number
# arrival_date_day_of_month
# stays_in_weekend_nights
# stays_in_week_nights
# adults
# children
# babies
# is_repeated_guest
# previous_cancellations
# previous_bookings_not_canceled
# booking_changes
# agent
# company
# days_in_waiting_list
# adr
# required_car_parking_spaces
# total_of_special_requests

# %%
# Print All Categorical Columns
for i in df.select_dtypes(include ='object').columns:
    print(i)
# Out:
# hotel
# arrival_date_month
# meal
# country
# market_segment
# distribution_channel
# reserved_room_type
# assigned_room_type
# deposit_type
# customer_type
# reservation_status
# reservation_status_date

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print(f'No. of Unique value in {i} is {df[i].nunique()}.')
# Out:
# No. of Unique value in hotel is 2.
# No. of Unique value in is_canceled is 2.
# No. of Unique value in lead_time is 479.
# No. of Unique value in arrival_date_year is 3.
# No. of Unique value in arrival_date_month is 12.
# No. of Unique value in arrival_date_week_number is 53.
# No. of Unique value in arrival_date_day_of_month is 31.
# No. of Unique value in stays_in_weekend_nights is 17.
# No. of Unique value in stays_in_week_nights is 35.
# No. of Unique value in adults is 14.
# No. of Unique value in children is 5.
# No. of Unique value in babies is 5.
# No. of Unique value in meal is 5.
# No. of Unique value in country is 177.
# No. of Unique value in market_segment is 8.
# No. of Unique value in distribution_channel is 5.
# No. of Unique value in is_repeated_guest is 2.
# No. of Unique value in previous_cancellations is 15.
# No. of Unique value in previous_bookings_not_canceled is 73.
# No. of Unique value in reserved_room_type is 10.
# ...

# %% [markdown]
# ## Variable Description

# %% [markdown]
# * **`hotel`** :-> Hotel (H1 = Resort Hotel or H2 = City Hotel)
# * **`is_canceled`** :-> Value indicating if the booking was canceled (1) or not (0)
# * **`lead_time`** :-> Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
# * **`arrival_date_year`** :-> Year of arrival date
# * **`arrival_date_month`** :-> Month of arrival date
# * **`arrival_date_week_number`** :-> Week number of year for arrival date
# * **`arrival_date_day_of_month`** :-> Day of arrival date
# * **`stays_in_weekend_nights`** :-> Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
# * **`stays_in_week_nights`** :-> Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
# * **`adults`** :-> Number of adults
# * **`children`** :-> Number of children
# * **`babies`** :-> Number of babies
# * **`meal`** :-> Type of meal booked. Categories are presented in standard hospitality meal packages: Undefined/SC – no meal package; BB – Bed & Breakfast; HB – Half board (breakfast and one other meal – usually dinner); FB – Full board (breakfast, lunch and dinner)
# * **`country`** :-> Country of origin. Categories are represented in the ISO 3155–3:2013 format
# * **`market_segment`** :-> Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# * **`distribution_channel`** :-> Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# * **`is_repeated_guest`** :-> Value indicating if the booking name was from a repeated guest (1) or not (0)
# * **`previous_cancellations`** :-> Number of previous bookings that were cancelled by the customer prior to the current booking
# * **`previous_bookings_not_canceled`** :-> Number of previous bookings not cancelled by the customer prior to the current booking
# * **`reserved_room_type`** :-> Code of room type reserved. Code is presented instead of designation for anonymity reasons.
# * **`assigned_room_type`** :-> Code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room type due to hotel operation reasons (e.g. overbooking) or by customer request. Code is presented instead of designation for anonymity reasons.
# * **`booking_changes`** :-> Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
# * **`deposit_type`** :-> Indication on if the customer made a deposit to guarantee the booking. This variable can assume three categories: No Deposit – no deposit was made; Non Refund – a deposit was made in the value of the total stay cost; Refundable – a deposit was made with a value under the total cost of stay.
# * **`agent`** :-> ID of the travel agency that made the booking
# * **`company`** :-> ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
# * **`days_in_waiting_list`** :-> Number of days the booking was in the waiting list before it was confirmed to the customer
# * **`customer_type`** :-> Type of booking, assuming one of four categories: Contract - when the booking has an allotment or other type of contract associated to it; Group – when the booking is associated to a group; Transient – when the booking is not part of a group or contract, and is not associated to other transient booking; Transient-party – when the booking is transient, but is associated to at least other transient booking
# * **`adr`** :-> Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
# * **`required_car_parking_spaces`** :-> Number of car parking spaces required by the customer
# * **`total_of_special_requests`** :-> Number of special requests made by the customer (e.g. twin bed or high floor)
# * **`reservation_status`** :-> Reservation last status, assuming one of three categories: Canceled – booking was canceled by the customer; Check-Out – customer has checked in but already departed; No-Show – customer did not check-in and did inform the hotel of the reason why
# * **`reservation_status_date`** :-> Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# ## Check Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 31994

# %% [markdown]
# ## Check Missing value

# %%
# Missing Values/Null Values Count
df.isnull().sum().sort_values(ascending=False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
# column wise percent missing value
percent_missing = round(100*(df.isnull().sum()/len(df)),4)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', ascending= False)
# Out:
#                                                    column_name  \
# company                                                company
# agent                                                    agent
# country                                                country
# children                                              children
# reserved_room_type                          reserved_room_type
# assigned_room_type                          assigned_room_type
# booking_changes                                booking_changes
# deposit_type                                      deposit_type
# hotel                                                    hotel
# previous_cancellations                  previous_cancellations
# days_in_waiting_list                      days_in_waiting_list
# customer_type                                    customer_type
# adr                                                        adr
# required_car_parking_spaces        required_car_parking_spaces
# ...

# %%
# Checking Null Value by plotting Heatmap
plt.figure(figsize=(10,8),dpi = 250)
sns.heatmap(df.isnull(), cbar=False,cmap='viridis')
plt.show()

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Handling Duplicated Values

# %%
# Drop Dulicated Values
df = df.drop_duplicates()

# %%
# Check dataframe after droping duplicated rows
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87392 non-null  float64
#  11  babies                          87396 non-null  int64
# ...

# %% [markdown]
# ## Handling Missing Value

# %%
# Drop Company and agent column
df = df.drop(['company', 'agent'], axis = 1)

# %%
# Replace null value in country column with mode of this column
df['country'] = df['country'].fillna(df['country'].mode()[0])

# %%
# Replace null value in children column with 0
df['children'] = df['children'].fillna(0)

# %%
# Again Check Missing value of Dataframe
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# ## Changing Data Types of columns

# %%
# Make a list of Categorical Columns
cat_cols = ['hotel', 
            'is_canceled',
            'arrival_date_year',
           'arrival_date_month',
           'arrival_date_week_number',
           'arrival_date_day_of_month',
           'meal',
           'country',
           'market_segment',
           'distribution_channel',
           'is_repeated_guest',
           'reserved_room_type',
           'assigned_room_type',
           'deposit_type',
           'customer_type',
           'required_car_parking_spaces',
           'total_of_special_requests',
           'reservation_status',
           'reservation_status_date']

# %%
# Print Categorical Columns
print(cat_cols)
# Out:
# ['hotel', 'is_canceled', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
# Make a list of Numerical columns
total_cols = df.columns.to_list()
num_cols = list(set(total_cols)- set(cat_cols))

# %%
# Print Numerical Column
print(num_cols)
# Out:
# ['adults', 'children', 'lead_time', 'previous_cancellations', 'babies', 'stays_in_week_nights', 'previous_bookings_not_canceled', 'adr', 'booking_changes', 'days_in_waiting_list', 'stays_in_weekend_nights']

# %%
# Change Data Types of categorical column to 'Object'
df[cat_cols] = df[cat_cols].apply(lambda x: x.astype(object))

# %%
# Change Data Types of Numerical column to 'int'
df[num_cols] = df[num_cols].apply(lambda x: x.astype(int))

# %%
# Again Check Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  object
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  object
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  object
#  6   arrival_date_day_of_month       87396 non-null  object
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  int64
#  11  babies                          87396 non-null  int64
# ...

# %% [markdown]
# ## Rename The column Name

# %%
## Rename column Name
df.columns = ['Hotel', 'IsCanceled', 'LeadTime', 'ArrivingYear', 'ArrivingMonth', 'ArrivingWeek','ArrivingDay', 'WeekendStay',
              'WeekStay', 'Adults', 'Children', 'Babies', 'MealType','Country', 'MarketSegment', 'DistChannel','IsRepeatGuest', 'PrevCancel',
              'PrevBookNotCancel', 'ReservedRoomType','AssignRoomType', 'ChangeBooking', 'DepositType', 'WaitingDays', 
              'CustomerType', 'ADR','CarParkingSpace', 'SpecialRequest','ReservationStatus', 'ReservationDate']

# %%
# Again Check Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Hotel              87396 non-null  object
#  1   IsCanceled         87396 non-null  object
#  2   LeadTime           87396 non-null  int64
#  3   ArrivingYear       87396 non-null  object
#  4   ArrivingMonth      87396 non-null  object
#  5   ArrivingWeek       87396 non-null  object
#  6   ArrivingDay        87396 non-null  object
#  7   WeekendStay        87396 non-null  int64
#  8   WeekStay           87396 non-null  int64
#  9   Adults             87396 non-null  int64
#  10  Children           87396 non-null  int64
#  11  Babies             87396 non-null  int64
#  12  MealType           87396 non-null  object
#  13  Country            87396 non-null  object
#  14  MarketSegment      87396 non-null  object
#  15  DistChannel        87396 non-null  object
# ...

# %%
# Get Statistical Summary Of 'Object' Data Type
df.describe(include = 'O').T
# Out:
#                    count unique         top   freq
# Hotel              87396      2  City Hotel  53428
# IsCanceled         87396      2           0  63371
# ArrivingYear       87396      3        2016  42391
# ArrivingMonth      87396     12      August  11257
# ArrivingWeek       87396     53          33   2793
# ArrivingDay        87396     31          17   3020
# MealType           87396      5          BB  67978
# Country            87396    177         PRT  27905
# MarketSegment      87396      8   Online TA  51618
# DistChannel        87396      5       TA/TO  69141
# IsRepeatGuest      87396      2           0  83981
# ReservedRoomType   87396     10           A  56552
# AssignRoomType     87396     12           A  46313
# DepositType        87396      3  No Deposit  86251
# CustomerType       87396      4   Transient  71986
# CarParkingSpace    87396      5           0  80083
# SpecialRequest     87396      6           0  43894
# ...

# %%
# Get Statistical Summary Of 'int' Data Type
df.describe(exclude = 'O').T
# Out:
#                      count        mean        std  min   25%   50%    75%  \
# LeadTime           87396.0   79.891368  86.052325  0.0  11.0  49.0  125.0
# WeekendStay        87396.0    1.005263   1.031921  0.0   0.0   1.0    2.0
# WeekStay           87396.0    2.625395   2.053584  0.0   1.0   2.0    4.0
# Adults             87396.0    1.875795   0.626500  0.0   2.0   2.0    2.0
# Children           87396.0    0.138633   0.455871  0.0   0.0   0.0    0.0
# Babies             87396.0    0.010824   0.113597  0.0   0.0   0.0    0.0
# PrevCancel         87396.0    0.030413   0.369145  0.0   0.0   0.0    0.0
# PrevBookNotCancel  87396.0    0.183990   1.731894  0.0   0.0   0.0    0.0
# ChangeBooking      87396.0    0.271603   0.727245  0.0   0.0   0.0    0.0
# WaitingDays        87396.0    0.749565  10.015731  0.0   0.0   0.0    0.0
# ADR                87396.0  106.099513  55.009810 -6.0  72.0  98.0  134.0
#
#                       max
# LeadTime            737.0
# ...

# %% [markdown]
# ## Add Some Important Column

# %%
# Lets add arrival date and convert it  to datetime
df['ArrivalDate'] = df['ArrivingDay'].astype(str) + '-' + df['ArrivingMonth'].astype(str) + '-' + df['ArrivingYear'].astype(str)
df['ArrivalDate'] = pd.to_datetime(df['ArrivalDate'], errors='coerce')

# %%
df.head()
# Out:
#           Hotel IsCanceled  LeadTime ArrivingYear ArrivingMonth ArrivingWeek  \
# 0  Resort Hotel          0       342         2015          July           27
# 1  Resort Hotel          0       737         2015          July           27
# 2  Resort Hotel          0         7         2015          July           27
# 3  Resort Hotel          0        13         2015          July           27
# 4  Resort Hotel          0        14         2015          July           27
#
#   ArrivingDay  WeekendStay  WeekStay  Adults  Children  Babies MealType  \
# 0           1            0         0       2         0       0       BB
# 1           1            0         0       2         0       0       BB
# 2           1            0         1       1         0       0       BB
# 3           1            0         1       1         0       0       BB
# 4           1            0         2       2         0       0       BB
#
#   Country MarketSegment DistChannel IsRepeatGuest  PrevCancel  \
# ...

# %%
# We can drop ArrivingYear, ArrivingMonth, ArrivingWeek, ArrivingDay Column
df = df.drop(['ArrivingYear', 'ArrivingMonth', 'ArrivingWeek', 'ArrivingDay'], axis = 1)

# %%
df.head()
# Out:
#           Hotel IsCanceled  LeadTime  WeekendStay  WeekStay  Adults  Children  \
# 0  Resort Hotel          0       342            0         0       2         0
# 1  Resort Hotel          0       737            0         0       2         0
# 2  Resort Hotel          0         7            0         1       1         0
# 3  Resort Hotel          0        13            0         1       1         0
# 4  Resort Hotel          0        14            0         2       2         0
#
#    Babies MealType Country MarketSegment DistChannel IsRepeatGuest  \
# 0       0       BB     PRT        Direct      Direct             0
# 1       0       BB     PRT        Direct      Direct             0
# 2       0       BB     GBR        Direct      Direct             0
# 3       0       BB     GBR     Corporate   Corporate             0
# 4       0       BB     GBR     Online TA       TA/TO             0
#
#    PrevCancel  PrevBookNotCancel ReservedRoomType AssignRoomType  \
# ...

# %%
# Lets Add Total Stay 
df['TotalStay'] = df['WeekendStay'] + df['WeekStay']

# %%
df.head()
# Out:
#           Hotel IsCanceled  LeadTime  WeekendStay  WeekStay  Adults  Children  \
# 0  Resort Hotel          0       342            0         0       2         0
# 1  Resort Hotel          0       737            0         0       2         0
# 2  Resort Hotel          0         7            0         1       1         0
# 3  Resort Hotel          0        13            0         1       1         0
# 4  Resort Hotel          0        14            0         2       2         0
#
#    Babies MealType Country MarketSegment DistChannel IsRepeatGuest  \
# 0       0       BB     PRT        Direct      Direct             0
# 1       0       BB     PRT        Direct      Direct             0
# 2       0       BB     GBR        Direct      Direct             0
# 3       0       BB     GBR     Corporate   Corporate             0
# 4       0       BB     GBR     Online TA       TA/TO             0
#
#    PrevCancel  PrevBookNotCancel ReservedRoomType AssignRoomType  \
# ...

# %%
# Lets Add Total Person 
df['TotalPerson'] = df['Adults'] + df['Children'] + df['Babies']

# %%
df.head()
# Out:
#           Hotel IsCanceled  LeadTime  WeekendStay  WeekStay  Adults  Children  \
# 0  Resort Hotel          0       342            0         0       2         0
# 1  Resort Hotel          0       737            0         0       2         0
# 2  Resort Hotel          0         7            0         1       1         0
# 3  Resort Hotel          0        13            0         1       1         0
# 4  Resort Hotel          0        14            0         2       2         0
#
#    Babies MealType Country MarketSegment DistChannel IsRepeatGuest  \
# 0       0       BB     PRT        Direct      Direct             0
# 1       0       BB     PRT        Direct      Direct             0
# 2       0       BB     GBR        Direct      Direct             0
# 3       0       BB     GBR     Corporate   Corporate             0
# 4       0       BB     GBR     Online TA       TA/TO             0
#
#    PrevCancel  PrevBookNotCancel ReservedRoomType AssignRoomType  \
# ...

# %%
# Lets Add Total Revenue
df['TotalRevenue'] = df['ADR']*df['TotalStay']

# %%
# Get List of alpha_2 code and alpha_3 code
list_alpha_2 = [i.alpha_2 for i in list(pycountry.countries)]
list_alpha_3 = [i.alpha_3 for i in list(pycountry.countries)]

# %%
# Function for geeting full country name from country code
def get_country_name(df):
    try:
        if (len(df['Country'])==2 and df['Country'] in list_alpha_2):
            return pycountry.countries.get(alpha_2=df['Country']).name
        elif (len(df['Country'])==3 and df['Country'] in list_alpha_3):
            return pycountry.countries.get(alpha_3=df['Country']).name
    except:
        return 'Not Found'

# %%
# Add new column Countryame
df['CountryName'] = df.apply(get_country_name, axis = 1)

# %%
# Drop country column
df = df.drop('Country', axis = 1)

# %%
df.head()
# Out:
#           Hotel IsCanceled  LeadTime  WeekendStay  WeekStay  Adults  Children  \
# 0  Resort Hotel          0       342            0         0       2         0
# 1  Resort Hotel          0       737            0         0       2         0
# 2  Resort Hotel          0         7            0         1       1         0
# 3  Resort Hotel          0        13            0         1       1         0
# 4  Resort Hotel          0        14            0         2       2         0
#
#    Babies MealType MarketSegment DistChannel IsRepeatGuest  PrevCancel  \
# 0       0       BB        Direct      Direct             0           0
# 1       0       BB        Direct      Direct             0           0
# 2       0       BB        Direct      Direct             0           0
# 3       0       BB     Corporate   Corporate             0           0
# 4       0       BB     Online TA       TA/TO             0           0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Hotel              87396 non-null  object
#  1   IsCanceled         87396 non-null  object
#  2   LeadTime           87396 non-null  int64
#  3   WeekendStay        87396 non-null  int64
#  4   WeekStay           87396 non-null  int64
#  5   Adults             87396 non-null  int64
#  6   Children           87396 non-null  int64
#  7   Babies             87396 non-null  int64
#  8   MealType           87396 non-null  object
#  9   MarketSegment      87396 non-null  object
#  10  DistChannel        87396 non-null  object
#  11  IsRepeatGuest      87396 non-null  object
#  12  PrevCancel         87396 non-null  int64
#  13  PrevBookNotCancel  87396 non-null  int64
#  14  ReservedRoomType   87396 non-null  object
#  15  AssignRoomType     87396 non-null  object
# ...

# %%
# Get Statistical Summary Of 'Object' Data Type
df.describe(include = 'O').T
# Out:
#                    count unique         top   freq
# Hotel              87396      2  City Hotel  53428
# IsCanceled         87396      2           0  63371
# MealType           87396      5          BB  67978
# MarketSegment      87396      8   Online TA  51618
# DistChannel        87396      5       TA/TO  69141
# IsRepeatGuest      87396      2           0  83981
# ReservedRoomType   87396     10           A  56552
# AssignRoomType     87396     12           A  46313
# DepositType        87396      3  No Deposit  86251
# CustomerType       87396      4   Transient  71986
# CarParkingSpace    87396      5           0  80083
# SpecialRequest     87396      6           0  43894
# ReservationStatus  87396      3   Check-Out  63371
# ReservationDate    87396    926  2016-02-14    211
# CountryName        87393    175    Portugal  27905

# %%
# Get Statistical Summary Of 'int' Data Type
df.describe(exclude = 'O',datetime_is_numeric=True).T
# Out:
#                      count                           mean  \
# LeadTime           87396.0                      79.891368
# WeekendStay        87396.0                       1.005263
# WeekStay           87396.0                       2.625395
# Adults             87396.0                       1.875795
# Children           87396.0                       0.138633
# Babies             87396.0                       0.010824
# PrevCancel         87396.0                       0.030413
# PrevBookNotCancel  87396.0                        0.18399
# ChangeBooking      87396.0                       0.271603
# WaitingDays        87396.0                       0.749565
# ADR                87396.0                     106.099513
# ArrivalDate          87396  2016-09-15 00:20:26.857064448
# TotalStay          87396.0                       3.630658
# TotalPerson        87396.0                       2.025253
# TotalRevenue       87396.0                     393.217847
#
# ...

# %% [markdown]
# # Exploratry Data Analysis

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Hotel

# %%
# Count of Hotel types
df['Hotel'].value_counts()
# Out:
# City Hotel      53428
# Resort Hotel    33968
# Name: Hotel, dtype: int64

# %%
# Percentage Distribution of Hotel
round(df['Hotel'].value_counts(normalize=True)*100,2)
# Out:
# City Hotel      61.13
# Resort Hotel    38.87
# Name: Hotel, dtype: float64

# %%
# Percentage Distribution of Hotel using pie chart
plt.figure(dpi = 200)
df['Hotel'].value_counts().plot(kind = 'pie', 
                                colors = sns.color_palette('Set1'),
                                autopct='%.0f%%')
plt.legend(bbox_to_anchor=(1.2,0.6))
plt.title('Percentage Distribution of Hotel')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### IsCanceled

# %%
# Count of IsCanceled
df['IsCanceled'].value_counts()
# Out:
# 0    63371
# 1    24025
# Name: IsCanceled, dtype: int64

# %%
# Percentage Distribution of IsCanceled
round(df['IsCanceled'].value_counts(normalize=True)*100,2)
# Out:
# 0    72.51
# 1    27.49
# Name: IsCanceled, dtype: float64

# %%
# Percentage Distribution of IsCanceled using pie chart
plt.figure(dpi = 200)
df['IsCanceled'].value_counts().plot(kind = 'pie', 
                                     colors = sns.color_palette('Set1'),
                                     autopct='%.0f%%')
plt.legend(bbox_to_anchor=(1.2,0.6))
plt.title('Percentage Distribution of IsCanceled')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### MealType

# %%
df['MealType'].value_counts()
# Out:
# BB           67978
# SC            9481
# HB            9085
# Undefined      492
# FB             360
# Name: MealType, dtype: int64

# %%
round(df['MealType'].value_counts(normalize = True)*100,2)
# Out:
# BB           77.78
# SC           10.85
# HB           10.40
# Undefined     0.56
# FB            0.41
# Name: MealType, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'MealType', 
              palette = 'Set1',
              order = df['MealType'].value_counts().index)
plt.show()

# %% [markdown]
# ### Country

# %%
df['CountryName'].value_counts().head(10)
# Out:
# Portugal          27905
# United Kingdom    10433
# France             8837
# Spain              7252
# Germany            5387
# Italy              3066
# Ireland            3016
# Belgium            2081
# Brazil             1995
# Netherlands        1911
# Name: CountryName, dtype: int64

# %%
round(df['CountryName'].value_counts(normalize = True).head(10)*100,2)
# Out:
# Portugal          31.93
# United Kingdom    11.94
# France            10.11
# Spain              8.30
# Germany            6.16
# Italy              3.51
# Ireland            3.45
# Belgium            2.38
# Brazil             2.28
# Netherlands        2.19
# Name: CountryName, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'CountryName', 
              palette = 'Set1',
              order = df['CountryName'].value_counts().head(10).index)
plt.show()

# %% [markdown]
# ### MarketSegment

# %%
df['MarketSegment'].value_counts()
# Out:
# Online TA        51618
# Offline TA/TO    13889
# Direct           11804
# Groups            4942
# Corporate         4212
# Complementary      702
# Aviation           227
# Undefined            2
# Name: MarketSegment, dtype: int64

# %%
round(df['MarketSegment'].value_counts(normalize = True)*100,4)
# Out:
# Online TA        59.0622
# Offline TA/TO    15.8920
# Direct           13.5063
# Groups            5.6547
# Corporate         4.8194
# Complementary     0.8032
# Aviation          0.2597
# Undefined         0.0023
# Name: MarketSegment, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'MarketSegment', 
              palette = 'Set1',
              order = df['MarketSegment'].value_counts().head(3).index)
plt.show()

# %% [markdown]
# ### DistChannel

# %%
df['DistChannel'].value_counts()
# Out:
# TA/TO        69141
# Direct       12988
# Corporate     5081
# GDS            181
# Undefined        5
# Name: DistChannel, dtype: int64

# %%
round(df['DistChannel'].value_counts(normalize = True)*100,4)
# Out:
# TA/TO        79.1123
# Direct       14.8611
# Corporate     5.8138
# GDS           0.2071
# Undefined     0.0057
# Name: DistChannel, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'DistChannel', 
              palette = 'Set1',
              order = df['DistChannel'].value_counts().head(3).index)
plt.show()

# %% [markdown]
# ### IsRepeatGuest

# %%
df['IsRepeatGuest'].value_counts()
# Out:
# 0    83981
# 1     3415
# Name: IsRepeatGuest, dtype: int64

# %%
round(df['IsRepeatGuest'].value_counts(normalize = True)*100,2)
# Out:
# 0    96.09
# 1     3.91
# Name: IsRepeatGuest, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'IsRepeatGuest', 
              palette = 'Set1',
              order = df['IsRepeatGuest'].value_counts().index)
plt.show()

# %% [markdown]
# ### ReservedRoomType

# %%
df['ReservedRoomType'].value_counts()
# Out:
# A    56552
# D    17398
# E     6049
# F     2823
# G     2052
# B      999
# C      915
# H      596
# L        6
# P        6
# Name: ReservedRoomType, dtype: int64

# %%
round(df['ReservedRoomType'].value_counts(normalize = True)*100,4)
# Out:
# A    64.7078
# D    19.9071
# E     6.9214
# F     3.2301
# G     2.3479
# B     1.1431
# C     1.0470
# H     0.6820
# L     0.0069
# P     0.0069
# Name: ReservedRoomType, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'ReservedRoomType', 
              palette = 'Set1',
              order = df['ReservedRoomType'].value_counts().index)
plt.show()

# %% [markdown]
# ### AssignRoomType

# %%
df['AssignRoomType'].value_counts()
# Out:
# A    46313
# D    22432
# E     7195
# F     3627
# G     2498
# C     2165
# B     1820
# H      706
# I      357
# K      276
# P        6
# L        1
# Name: AssignRoomType, dtype: int64

# %%
round(df['AssignRoomType'].value_counts(normalize = True)*100,4)
# Out:
# A    52.9921
# D    25.6671
# E     8.2326
# F     4.1501
# G     2.8583
# C     2.4772
# B     2.0825
# H     0.8078
# I     0.4085
# K     0.3158
# P     0.0069
# L     0.0011
# Name: AssignRoomType, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'AssignRoomType', 
              palette = 'Set1',
              order = df['AssignRoomType'].value_counts().index)
plt.show()

# %% [markdown]
# ### DepositType

# %%
df['DepositType'].value_counts()
# Out:
# No Deposit    86251
# Non Refund     1038
# Refundable      107
# Name: DepositType, dtype: int64

# %%
round(df['DepositType'].value_counts(normalize = True)*100,2)
# Out:
# No Deposit    98.69
# Non Refund     1.19
# Refundable     0.12
# Name: DepositType, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'DepositType', 
              palette = 'Set1',
              order = df['DepositType'].value_counts().index)
plt.show()

# %% [markdown]
# ### CustomerType

# %%
df['CustomerType'].value_counts()
# Out:
# Transient          71986
# Transient-Party    11727
# Contract            3139
# Group                544
# Name: CustomerType, dtype: int64

# %%
round(df['CustomerType'].value_counts(normalize = True)*100,2)
# Out:
# Transient          82.37
# Transient-Party    13.42
# Contract            3.59
# Group               0.62
# Name: CustomerType, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'CustomerType', 
              palette = 'Set1',
              order = df['CustomerType'].value_counts().index)
plt.show()

# %% [markdown]
# ### CarParkingSpace

# %%
df['CarParkingSpace'].value_counts()
# Out:
# 0    80083
# 1     7280
# 2       28
# 3        3
# 8        2
# Name: CarParkingSpace, dtype: int64

# %%
round(df['CarParkingSpace'].value_counts(normalize = True)*100,4)
# Out:
# 0    91.6323
# 1     8.3299
# 2     0.0320
# 3     0.0034
# 8     0.0023
# Name: CarParkingSpace, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'CarParkingSpace', 
              palette = 'Set1',
              order = df['CarParkingSpace'].value_counts().index)
plt.show()

# %% [markdown]
# ### SpecialRequest

# %%
df['SpecialRequest'].value_counts()
# Out:
# 0    43894
# 1    29017
# 2    11812
# 3     2317
# 4      320
# 5       36
# Name: SpecialRequest, dtype: int64

# %%
round(df['SpecialRequest'].value_counts(normalize = True)*100,2)
# Out:
# 0    50.22
# 1    33.20
# 2    13.52
# 3     2.65
# 4     0.37
# 5     0.04
# Name: SpecialRequest, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'SpecialRequest', 
              palette = 'Set1',
              order = df['SpecialRequest'].value_counts().index)
plt.show()

# %% [markdown]
# ### ReservationStatus

# %%
df['ReservationStatus'].value_counts()
# Out:
# Check-Out    63371
# Canceled     23011
# No-Show       1014
# Name: ReservationStatus, dtype: int64

# %%
round(df['ReservationStatus'].value_counts(normalize = True)*100,2)
# Out:
# Check-Out    72.51
# Canceled     26.33
# No-Show       1.16
# Name: ReservationStatus, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'ReservationStatus', 
              palette = 'Set1',
              order = df['ReservationStatus'].value_counts().index)
plt.show()

# %% [markdown]
# ### ArrivalDate Yearly

# %%
df['ArrivalDate'].dt.isocalendar().year.value_counts()
# Out:
# 2016    42283
# 2017    31606
# 2015    13507
# Name: year, dtype: Int64

# %%
round(100*df['ArrivalDate'].dt.isocalendar().year.value_counts(normalize = True),2)
# Out:
# 2016    48.38
# 2017    36.16
# 2015    15.45
# Name: year, dtype: Float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 180)
sns.countplot(x = df['ArrivalDate'].dt.isocalendar().year,
              palette = 'Set1',
             order = df['ArrivalDate'].dt.isocalendar().year.value_counts().index)
plt.show()

# %% [markdown]
# ### ArrivalDate Quarterly

# %%
df['ArrivalDate'].dt.quarter.value_counts()
# Out:
# 3    28004
# 2    24028
# 1    18304
# 4    17060
# Name: ArrivalDate, dtype: int64

# %%
round(100*df['ArrivalDate'].dt.quarter.value_counts(normalize = True),2)
# Out:
# 3    32.04
# 2    27.49
# 1    20.94
# 4    19.52
# Name: ArrivalDate, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 180)
sns.countplot(x = df['ArrivalDate'].dt.quarter,
              palette = 'Set1',
             order = df['ArrivalDate'].dt.quarter.value_counts().index)
plt.show()

# %% [markdown]
# ### ArrivalDate Monthly

# %%
df['ArrivalDate'].dt.month.value_counts()
# Out:
# 8     11257
# 7     10057
# 5      8355
# 4      7908
# 6      7765
# 3      7513
# 10     6934
# 9      6690
# 2      6098
# 12     5131
# 11     4995
# 1      4693
# Name: ArrivalDate, dtype: int64

# %%
round(100*df['ArrivalDate'].dt.month.value_counts(normalize = True),2)
# Out:
# 8     12.88
# 7     11.51
# 5      9.56
# 4      9.05
# 6      8.88
# 3      8.60
# 10     7.93
# 9      7.65
# 2      6.98
# 12     5.87
# 11     5.72
# 1      5.37
# Name: ArrivalDate, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 180)
sns.countplot(x = df['ArrivalDate'].dt.month,
              palette = 'Set1',
             order = df['ArrivalDate'].dt.month.value_counts().index)
plt.show()

# %% [markdown]
# ### ArrivalDate Weekly

# %%
df['ArrivalDate'].dt.isocalendar().week.value_counts().head(10)
# Out:
# 33    2811
# 32    2527
# 31    2461
# 34    2458
# 28    2338
# 30    2260
# 29    2195
# 27    2152
# 20    1966
# 17    1965
# Name: week, dtype: Int64

# %%
round(100*(df['ArrivalDate'].dt.isocalendar().week.value_counts(normalize = True)),2).head(10)
# Out:
# 33    3.22
# 32    2.89
# 31    2.82
# 34    2.81
# 28    2.68
# 30    2.59
# 29    2.51
# 27    2.46
# 20    2.25
# 17    2.25
# Name: week, dtype: Float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 180)
sns.countplot(x = df['ArrivalDate'].dt.isocalendar().week,
              palette = 'Set1',
             order = df['ArrivalDate'].dt.isocalendar().week.value_counts().head(10).index)
plt.show()

# %% [markdown]
# ### TotalRevenue

# %%
sns.set_style('white')
plt.figure(figsize= (6,12), dpi = 180)
sns.boxplot(data = df,
            y = 'TotalRevenue',
           color = 'green')
plt.show()

# %% [markdown]
# ### TotalStay

# %%
df['TotalStay'].value_counts().head(10)
# Out:
# 3     17839
# 1     17184
# 2     15745
# 4     13575
# 7      7527
# 5      6742
# 6      3271
# 10     1076
# 8      1067
# 14      862
# Name: TotalStay, dtype: int64

# %%
round(df['TotalStay'].value_counts(normalize = True).head(10)*100,2)
# Out:
# 3     20.41
# 1     19.66
# 2     18.02
# 4     15.53
# 7      8.61
# 5      7.71
# 6      3.74
# 10     1.23
# 8      1.22
# 14     0.99
# Name: TotalStay, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'TotalStay', 
              palette = 'Set1',
              order = df['TotalStay'].value_counts().head(10).index)
plt.show()

# %% [markdown]
# ### TotalPerson

# %%
df['TotalPerson'].value_counts()
# Out:
# 2     57057
# 1     16072
# 3     10078
# 4      3870
# 0       166
# 5       136
# 26        5
# 12        2
# 27        2
# 20        2
# 10        2
# 40        1
# 50        1
# 55        1
# 6         1
# Name: TotalPerson, dtype: int64

# %%
round(df['TotalPerson'].value_counts(normalize = True)*100,2)
# Out:
# 2     65.29
# 1     18.39
# 3     11.53
# 4      4.43
# 0      0.19
# 5      0.16
# 26     0.01
# 12     0.00
# 27     0.00
# 20     0.00
# 10     0.00
# 40     0.00
# 50     0.00
# 55     0.00
# 6      0.00
# Name: TotalPerson, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize= (10,6), dpi = 200)
sns.countplot(data= df, 
              x = 'TotalPerson', 
              palette = 'Set1',
              order = df['TotalPerson'].value_counts().index)
plt.show()
